# %%
import cv2
import numpy as np
import pytesseract

pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract'
from PIL import Image

img=Image.open('Btest.png')
result=pytesseract.image_to_string(img)
print("Wynik: "+result)
img=Image.open('sam5.png')
result=pytesseract.image_to_string(img)
print("Wynik: "+result)
# Out:
# Wynik: DU VB 523
# Wynik:
